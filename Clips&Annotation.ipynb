# %%
# import package
from IPython.display import YouTubeVideo

# %% [markdown]
# # Please Annotate based on this website:
# # https://imotions.com/blog/facial-action-coding-system/
# # Also pay attention to audio features(ie. pitch)
# # And each clip should be annotated twice
#
# Per timestamp:
# First line is openface-related annotations
# Second line is audio-related annotations

# %% [markdown]
# # Flirting Action Clips

# %% [markdown]
# True.Blood.S01E02.720p.HDTV.x264-2HD-1 (1)
# Smile + inviting action + prolonged eye contact
#
# True.Blood.S01E02.720p.HDTV.x264-2HD-0 (1)
# Eye glance + prolonged eye contact

# %% [markdown]
# True.Blood.S01E01.720p.HDTV.x264-2HD-2 (1)
# Eye contacting + smiling + looking up and down
#
# True.Blood.S01E01.720p.HDTV.x264-2HD-1 (1)
# smiling, drawing attention to lips, prolonged eye contact
#
# True.Blood.S01E01.720p.HDTV.x264-2HD-0 (0)
# prolonged eye contact, comfortable movements (shimmy), smiling

# %% [markdown]
# Flirt5: Prolonged eye contact, physical contact, saying “I love you”
#
# Flirt4: Smiling, physical contact, playful tone of voice
#
# Flirt3: Flirty speech, smiling
#
# Flirt2: Eye contact, physical contact, smiling
#
# Flirt1: Smiling, eye contact, complementing

# %%
# 54 total flirting clips
YOUTUBE_ID = 'VxaOP79X0P4'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1*** Eye glance + nod + smirk + narrow eyes + low pitched tone of voiceraises

# %%
# 1 clips from this video
YOUTUBE_ID = 'qUxXbU2ModY'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1*** twisting body + laugh + head tilt right

# %%
# 1 clips from this video
YOUTUBE_ID = 'NycP2RIqCh8'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1*** Focus on lips, eye contact, smile, sound of pleasure

# %%
# 1 clips from this video
YOUTUBE_ID = 'eE0llk5Cxok'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1*** Hand gesture + Soft tone of voice + prolonged eye contact

# %%
# 2 clips from this video
YOUTUBE_ID = '8YbTIJsI5S0'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1*** Context + shy + Unsustained eye contact + clenched teeth + smiling
#
# ***2*** Smiling, physical touch, complementing

# %%
# 4 clips from this video
YOUTUBE_ID = '1v98t9YKPmc'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1*** Finding commonalities, laughing, smiling
#
# ***2*** Smiling, compliment, wink
#
# ***3*** Physical touch, smiling, eye contact
#
# ***4*** Physical touch, smiling, lower pitch voice from man/higher pitch voice from woman

# %%
# 6 clips from this video
YOUTUBE_ID = 'qkq9k5FewvI'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:37 1:40:** Recline and Touching head + Squinting with a smile
#
# **1:41 1:42:** Right hand is leaning on the sofa + Squinting with a smile
#
# Whispering + deeper, slower voice
#
# **2:07 2:09:** Biting lip Sign
#
# **3:21 3:24:** Head up + squinting with a smile
#
# warmly (saying: it’s been too long since I’ve seen you)
#
# **3:30 3:35:** leaning on sofa + touching head + smile
#
# Questioning soft tone
#
# **6:05 6:12:** leaning on the sofa + pursing her lip
#
# Soft laughing

# %%
# 4 clips from this video
YOUTUBE_ID = '3qxH0R_k3zI'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:48 1:58:** staring + head movement + raising eyebrow + smile
#
# low, throaty voice
#
# **2:02 2:13:** staring + head movement + raising eyebrow + smile
#
# low, throaty voice, raising over clip
#
# **2:36 2:42:** touching face + head tilt right + eyes looking down then up
#
#
# **2:50 2:53:** Head down + eyes up + raised corner of mouth

# %%
# 5 clips from this video
YOUTUBE_ID = 'WAkZz1hV7_c'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:05 1:08:** slit + lip funneler + eyes up
#
# hi-to-low repetition pattern
#
# **1:10 1:12:** lid droop + touching mouch
#
# clipped speech (quick, tight endings to words)
#
# **1:22 1:27:** head turn right + look away then back + lip droop + head small movement + smile
#
# smacking lips?
#
# **1:30 1:34:** head turn right + look down + slit + brow lowerer
#
# chewing gum, suggestive tone
#
#
# **1:39 1:45:** lips part + staring + look down
#
# throaty voice

# %%
# 5 clips from this video
YOUTUBE_ID = 'z42hs7HOabE'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:28 0:36:** Raising left side of brow + twisting body + smile
#
# **0:38 0:43:** playing with hands + mouth open
#
# questioning tone
#
# **0:53 0:58:** shaking head + looking up + smile
#
# breathy, deeper voice
#
# **1:47 1:50:** raising brow + big smile + head down + looking up
#
# low and then quesitoning
#
# **1:54 1:57:** look up and down
#
# tone is suggestive

# %%
# 4 clips from this video
YOUTUBE_ID = 'htqVcFHiblQ'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:24 0:28:** Head tilt right + looking down and up + smile
#
# hi-low-hi pattern
#
# **0:30 0:39:** touching hair + head tilt left + eyes turn left
#
# **4:42 4:50:** touching mouth + twisting body + head turn left + raising brow + looking down
#
# low ending high
#
# **5:08 5:13:** head forward (to get closer) + rasing brow
#
# throaty

# %%
# 2 clips from this video
YOUTUBE_ID = '5Vl8Wp3aBwQ'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:46 0:52:** smiling, describing a comic book character as hot
#
# noticable exhalation, a little breathy
#
# **1:23 1:33:** walk into personal space, both nodding
#
# low questioning, higher response

# %%
# 4 clips from this video
YOUTUBE_ID = '7NOL6H2kZaE'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:51 1:59:** smiling, laughing, looking into each other's eyes
#
# low challenge, high response
#
# **2:20 2:26:** take paper from the other person, laughing, smiling
#
# laughter
#
# **3:19 3:21:** looking into each other's eyes
#
# deep and hoarse voice
#
# **4:54 4:58:** locked gaze with each other, dancing
#
# singing with laughter in response.

# %%
# 4 clips from this video
YOUTUBE_ID = 'pNqEDwpIm9I'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:41 1:47:** both people smiling, squinted eye
#
# audio is unrelated music
#
#
# **1:54 1:57:** tap in the nose with dolphin balloon, close eyes
#
# audio is unrelated music
#
# **2:07 2:11:** smiling
#
# audio is unrelated music
#
#
# **2:48 2:53:**
#
# steady expectant gaze, other smiles and looks away abashedly
#
# audio is unrelated music

# %% [markdown]
# # Non-Flirting Action Clips

# %%
# how many nonflirting clips are there? (42 + 5)
# +3 from the Flirting w/ 40 which are not here = 50
# flirting clips (54 + 1) + non-flirting clips (50) = 105 clips

# %%
# 6 clip from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = 'htqVcFHiblQ'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# ***1:20 1:24*** knit brow + shake head
#                 绕
#
# ***1:49 1:51*** laugh awkwardly
#
# ***2:26 2:28*** head down + cry
#                 crying voice
#
# ***2:45 2:50*** staring + small head movement
#
# ***3:05 3:07*** mouth open widely + head toward
#                 yelling
#
# ***5:48 5:50*** raise upper lip + wrink nose

# %%
# 1 clip from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = 'Dyri6DRZltk'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:00 0:09:** shout, man uses a pair of nunchucks to light matches on fire

# %%
# 2 clips from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = 'pNqEDwpIm9I'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:34 0:37:** both bow, woman walks away
#
# **5:17 5:24:** doctor says something, patient is smiling and bows

# %%
# 7 clips from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = 'PJP-C7TCaM8'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:15 0:20:** crossed arms, yelling, shaking head
# **0:30 0:36:** disbelief, blowing on printer
# **1:10 1:17:** questioning tone, eyebrows raised, nod
# **1:46 1:51:** angry, loud tone, walk away
# **3:04 3:10:** shrug, AU 1 Inner Brow Raiser, eyes look upwards
# **3:47 3:51:** eyebrows raise, questioning tone
# **5:55 6:01:** eyes large, shake head

# %%
# 4 clips from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = 'pBaZo4IQ030'

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:25 1:33:** context: mock interview, self-introduction, have interest
# **2:50 2:56:** looking at interviewer, hand motion
# **4:22 4:27:** can perform her job tasks well within a month, hands make a victory motion
# **5:47 5:52:** scratch neck, look around, low volume

# %%
# 12 clips from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = "lyvAjZw6O_Q"

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:00 0:05:** conspirational tone, shake head once, AU 24 Lip Pressor
# **0:11 0:19:** shake head back and forth slightly, emphasize "important"
# **0:24 0:29:** low volume, AU 24 Lip Pressor
# **0:29 0:34:** AU 1 Inner Brow Raiser and AU 2 Outer Brow Raiser (both sides), nod once
# **0:45 0:49:** head goes from down inclination to up inclination, rising tone
# **0:50 0:55:** look down and AU 4 Brow Lowerer, AU 1 Inner Brow Raiser
# **1:21 1:26:** low volume, look down, walk towards David, says David's name in higher pitch
# **1:45 1:50:** looks at David, AU 24 Lip Pressor, AU 55 Head Tilt Left
# **1:53 1:57:** man with hat speaks a louder volume than David, David nods once and shakes head
# **2:02 2:07:** raise hands with palms up, walk away
# **2:15 2:20:** both walking, right hand raised, frustrated tone
# **2:40 2:45:** says 6:20, stare into the distance

# %%
# 11 clips from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = "ImEnWAVRLU0"

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **1:07 1:11**: nervous, says "You can do this," panting, context: looking in mirror
# **1:32 1:35**: eyes wide, AU 1 Inner Brow Raiser, eyes and head turn left, left hand and index finger point left
#
# **4:34 4:35**: (flirting) mouth open + wink
#
# **5:04 5:12**: shruggie + smile + shaking head
#
# **5:20 5:25**: point at something + raising brow + nodding
#
# **5:52 5:56**: series face + lip pressor + point at something
#
# **7:38 7:42**: shaking head + smile
#                sign + laugh
#
# **7:46 7:51**: thinking + eye up
#                sign
#
# **8:10 8:16**: head left + lip droop
#
# **8:17 8:20**: head right + eyes turn right
#
# **8:21 8:26**: curl one's lip + head left + eyes left

# %%
# 5 clips from this video
# This is annotated once (delete this after another teammate annotate and approve each clip)
YOUTUBE_ID = "v2VgA_MCNDg"

YouTubeVideo(YOUTUBE_ID)

# %% [markdown]
# **0:07 0:11**: shake head, AU 1 Inner Brow Raiser, eyes turn right, AU 5 Upper Lid Raiser, surprised (AU 1 Inner Brow Raiser, AU 2 Outer Brow Raiser, AU 5 Upper Lid Raiser, AU 26 Jaw Drop)
# **0:21 0:26:** AU 4 Brow Lowerer, AU 43 Eyes Closed, hands open and outstretched upwards, AU 25 Lips part, shake head rapidly, look at Phoebe, loud and rapid speech
# **0:29 0:34:** clasp hands, raise brows, shout "Bam!" and clap, look at Phoebe
#
# **2:30 2:32:** eyes open widely + head toward (surprise)
#               questioning voice
#
# **3:29 3:30** raise brow + nod (begging)
